# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import math

# %%
df = pd.read_csv("puzzle.csv", names=["latitude", "longitude"])
gdf = gpd.read_file("world_map/ne_10m_admin_0_countries.shp")[['ADM0_A3', 'geometry']].to_crs('+proj=robin')
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
df.head()
# Out:
#    latitude  longitude
# 0   0.39715   2.113629
# 1   0.39715   2.113629
# 2   0.39715   2.113629
# 3   0.39715   2.113629
# 4   0.39715   2.113629

# %%
plt.figure()
plt.scatter(x=df["longitude"], y=df["latitude"])

# %%
df["latitude"] = df["latitude"] * 180 / math.pi
df["longitude"] = df["longitude"] * 180 / math.pi

# %%
fig, ax = plt.subplots(figsize=(20, 20))
world.plot(ax=ax)
df.plot.scatter(ax=ax, x="longitude", y="latitude", c="red", s=1.8)
